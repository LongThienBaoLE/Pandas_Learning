# %% [markdown]
# ## GETTING STARTED

# %%
import pandas as pd

# %%
File1 = pd.read_csv('File1.csv')
File1
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135   9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318   9.497573
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213   9.671620
# ..                                                 ...    ...        ...
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
#     Nationality
# 0        France
# 1       Germany
# 2       Vietnam
# 3         Italy
# ...

# %% [markdown]
# ## Exercise of File1

# %% [markdown]
# ### 1. Ex1:
# - Get the 5th row in dataframe
# - Get the 3th column in dataframe

# %%
row_5 = File1.iloc[4]
row_5
# Out:
# SMILES         COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...
# IC50                                                       0.213
# pIC50                                                    9.67162
# Nationality                                                Japan
# Name: 4, dtype: object

# %%
column_3 = File1.iloc[:, 2]
column_3
# Out:
# 0      10.096910
# 1       9.869666
# 2       9.497573
# 3      10.065502
# 4       9.671620
#          ...
# 652     9.917215
# 653     9.869666
# 654    10.193820
# 655    10.086186
# 656     9.551294
# Name: pIC50, Length: 657, dtype: float64

# %% [markdown]
# ### 2. Ex2. Get the pIC50 of coumpound 3

# %%
File1['pIC50'][2]
# or File1.iloc[3]['pIC50']
# Out:
# 9.49757288

# %% [markdown]
# ### 3. Ex3: Number of compounds that have pIC50 >=9

# %%
File1[File1['pIC50'] >=9].shape[0]
# Out:
# 615

# %%
count = 0
for i in File1['pIC50']:
    if i >= 9:
        count +=1
count
# Out:
# 615

# %% [markdown]
# ### 4. Ex4: Dataframe without column 4

# %%
File1.columns
# Out:
# Index(['SMILES', 'IC50', 'pIC50', 'Nationality'], dtype='object')

# %%
File1.drop(columns=File1.columns[3])
# Out:
#                                                 SMILES   IC50      pIC50
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135   9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318   9.497573
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213   9.671620
# ..                                                 ...    ...        ...
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
# [657 rows x 3 columns]

# %% [markdown]
# ### 5. Ex5. Dataframe without rows (2, 4)

# %%
File1.drop([2, 4], axis=0)
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135   9.869666
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 5    COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.099  10.004365
# 6    COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.430   9.366532
# ..                                                 ...    ...        ...
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
#     Nationality
# 0        France
# 1       Germany
# 3         Italy
# 5        France
# ...

# %% [markdown]
# ### 6. Ex 6: Find min and max values of pIC50 (round to 2 decimal places)

# %%
round(File1['pIC50'].min(),2)
# Out:
# 8.03

# %%
round(File1['pIC50'].max(),2)
# Out:
# 10.22

# %% [markdown]
# ### 7. Ex7: Dataframe of compounds that have pIC50 >= 9

# %%
File1[File1['pIC50']>=9]
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135   9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318   9.497573
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213   9.671620
# ..                                                 ...    ...        ...
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
#     Nationality
# 0        France
# 1       Germany
# 2       Vietnam
# 3         Italy
# ...

# %% [markdown]
# ### 8. Ex8: Find mean and std of pIC50 (round to 3 decimal places)

# %%
round(File1['pIC50'].mean(),3)
# Out:
# 9.682

# %%
round(File1['pIC50'].std(),3)
# Out:
# 0.411

# %% [markdown]
# ### 9. Ex9: Dataframe of compounds that have pIC50 >= 9 and =< 10

# %%
File1[(File1['pIC50'] >=9) & (File1['pIC50'] <= 10)]
# Out:
#                                                 SMILES   IC50     pIC50  \
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135  9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318  9.497573
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213  9.671620
# 6    COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.430  9.366532
# 7    COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.590  9.229148
# ..                                                 ...    ...       ...
# 649  COC1=C(C=CC(=N1)C2=CC=CC(=C2Cl)C3=C(C(=CC=C3)C...  0.167  9.777284
# 651  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.196  9.707744
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121  9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135  9.869666
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281  9.551294
#
#     Nationality
# 1       Germany
# 2       Vietnam
# 4         Japan
# 6       Germany
# ...

# %% [markdown]
# ### 10. Ex10: Get the index of compounds that have pIC50 >=10.2

# %%
File1[File1['pIC50']>= 10.2].index
# Out:
# Index([25, 146, 147, 250, 284, 287], dtype='int64')

# %%
# Get the index of 2nd compound that have pIC50 >= 10.2
File1[File1['pIC50']>= 10.2].index[1]
# Out:
# 146

# %%
# Get the row of of 2nd compounds that have pIC50 >= 10.2
File1.iloc[File1[File1['pIC50']>= 10.2].index[2]]
# Out:
# SMILES         CC1(CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3Cl)C4=C(...
# IC50                                                        0.06
# pIC50                                                  10.221849
# Nationality                                              Vietnam
# Name: 147, dtype: object

# %% [markdown]
# ### 11. Ex11: Create a column named A, containing the value of IC50 minus pIC50

# %%
File1['A'] = File1['IC50'] - File1['pIC50']
File1
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135   9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318   9.497573
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213   9.671620
# ..                                                 ...    ...        ...
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
#     Nationality          A
# 0        France -10.016910
# 1       Germany  -9.734666
# ...

# %% [markdown]
# ### 13. Ex13: Create a column named B, containing the value of IC50 minus mean of pIC50

# %%
File1['B'] = File1['pIC50'] - File1['pIC50'].mean()
File1
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135   9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318   9.497573
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213   9.671620
# ..                                                 ...    ...        ...
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
#     Nationality          A         B
# 0        France -10.016910  0.415245
# ...

# %% [markdown]
# ### 14. Ex14: Create a column named 'Norm', containing the normalized vales of pIC50 - (pIC50 - mean)/std
# Kết quả: Giá trị của chất 0 ở cột Norm là 1.009212

# %%
File1['Norm'] = (File1['pIC50']-File1['pIC50'].mean())/File1['pIC50'].std()
File1
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135   9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318   9.497573
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213   9.671620
# ..                                                 ...    ...        ...
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
#     Nationality          A      Norm
# 0        France -10.016910  1.009212
# ...

# %% [markdown]
# ### 14. Ex14: Plot histograms of 'pIC50' and 'Norm'

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(File1['pIC50'])
# Out:
# (array([  6.,   7.,   6.,  16.,  22.,  55., 103., 155., 131., 156.]),
#  array([ 8.0347983 ,  8.25350334,  8.47220839,  8.69091343,  8.90961848,
#          9.12832352,  9.34702857,  9.56573361,  9.78443866, 10.0031437 ,
#         10.22184875]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(File1['Norm'])
# Out:
# (array([  6.,   7.,   6.,  16.,  22.,  55., 103., 155., 131., 156.]),
#  array([-4.00254424, -3.47100347, -2.93946269, -2.40792192, -1.87638115,
#         -1.34484037, -0.8132996 , -0.28175882,  0.24978195,  0.78132273,
#          1.3128635 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 15. Ex15:
# - Create a column named C, containing value 1 if pIC50 >= 10 or value 0 if pIC50 < 10
# - Create a culumn named D, containing value 2 if pIC50 >=10 or value 1 if 9 <= pIC50 < 10 or value 0 if pIC50 <9

# %%
File1['C'] = [1 if x >=10 else 0 for x in File1['pIC50']]
File1
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135   9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318   9.497573
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213   9.671620
# ..                                                 ...    ...        ...
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
#     Nationality          A      Norm  C  D
# 0        France -10.016910  1.009212  1  2
# ...

# %%
File1['D'] = [2 if x >10 else 1 if (x<10)&(x>=9) else 0 for x in File1['pIC50']]
File1
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135   9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318   9.497573
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213   9.671620
# ..                                                 ...    ...        ...
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
#     Nationality          A      Norm  C  D
# 0        France -10.016910  1.009212  1  2
# ...

# %% [markdown]
# ### 16. Ex16:
# - Create 2 dataframes with values in 'C' == 1 (df1) and == 0 (df2)
# - Concatenate 2 above dataframe to generate 'df'

# %%
df1 = File1[File1['C'] == 1]
df1
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 5    COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.099  10.004365
# 24   COC1=NC(=CN=C1CNCCOC(=O)N)C2=CC=CC(=C2Cl)C3=C(...  0.080  10.096910
# 25   COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.060  10.221849
# ..                                                 ...    ...        ...
# 647  CC1=CC(=NC(=C1CN2CC(C3(C2)CCOC3)C(=O)O)OC)C4=C...  0.071  10.148742
# 648  CC1=CC(=NC(=C1CN2C[C@@H]3CCC[C@@]3(C2)C(=O)O)O...  0.064  10.193820
# 650  COC1=NC(=CN=C1CN2CC(C2)OCC(=O)N)C3=CC=CC(=C3Cl...  0.064  10.193820
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
#
#     Nationality          A      Norm  C  D
# 0        France -10.016910  1.009212  1  2
# ...

# %%
df2 = File1[File1['C'] == 0]
df2
# Out:
#                                                 SMILES   IC50     pIC50  \
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135  9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318  9.497573
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213  9.671620
# 6    COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.430  9.366532
# 7    COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.590  9.229148
# ..                                                 ...    ...       ...
# 649  COC1=C(C=CC(=N1)C2=CC=CC(=C2Cl)C3=C(C(=CC=C3)C...  0.167  9.777284
# 651  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.196  9.707744
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121  9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135  9.869666
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281  9.551294
#
#     Nationality         A      Norm  C  D
# 1       Germany -9.734666  0.456919  0  1
# ...

# %%
df = pd.concat([df1, df2])
df
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 5    COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.099  10.004365
# 24   COC1=NC(=CN=C1CNCCOC(=O)N)C2=CC=CC(=C2Cl)C3=C(...  0.080  10.096910
# 25   COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.060  10.221849
# ..                                                 ...    ...        ...
# 649  COC1=C(C=CC(=N1)C2=CC=CC(=C2Cl)C3=C(C(=CC=C3)C...  0.167   9.777284
# 651  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.196   9.707744
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
#     Nationality          A      Norm  C  D
# 0        France -10.016910  1.009212  1  2
# ...

# %% [markdown]
# ### 17. Ex17: Generate a dataframe with pIC50 values in decreasing order

# %%
File1.sort_values('pIC50', ascending=False)
# Out:
#                                                 SMILES  IC50      pIC50  \
# 284  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.06  10.221849
# 287  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.06  10.221849
# 147  CC1(CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3Cl)C4=C(...  0.06  10.221849
# 250  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.06  10.221849
# 146  CC1(CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3Cl)C4=C(...  0.06  10.221849
# ..                                                 ...   ...        ...
# 86   COC1CN(C1)CC2=NC=C(N=C2SC)C3=CC=CC(=C3Cl)C4=C(...  5.88   8.230623
# 58   CNC1=NC(=CN=C1CN)C2=CC=CC(=C2Cl)C3=C(C(=CC=C3)...  6.76   8.170053
# 14   COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  7.51   8.124360
# 57   CNC1=NC(=CN=C1CNCC2CC(C2)O)C3=CC=CC(=C3Cl)C4=C...  8.78   8.056505
# 393  COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  9.23   8.034798
#
#     Nationality          A      Norm  C  D
# 284       Japan -10.161849  1.312863  1  2
# ...

# %% [markdown]
# ### 18. Ex18: In 'Nationality' columns, replace 'France, Germany, Italy, Japan' values with '0, 1, 2, 3, 4' values

# %%
File1['Nationality'].replace(['France', 'Germany', 'Vietnam', 'Italy', 'Japan'], [0, 1, 2 , 3, 4], inplace=True)
File1
# Out:
#                                                 SMILES   IC50      pIC50  \
# 0    COC1=NC(=CN=C1CN2CC3(C2)CCC(=O)N3)C4=CC=CC(=C4...  0.080  10.096910
# 1    COC1=NC(=CN=C1CN2CC(C2)O)C3=CC=CC(=C3F)C4=C(C(...  0.135   9.869666
# 2    COC1CN(C1)CC2=NC=C(N=C2OC)C3=CC=CC(=C3F)C4=C(C...  0.318   9.497573
# 3    CC(=O)N1CC2(C1)CN(C2)CC3=NC=C(N=C3OC)C4=CC=CC(...  0.086  10.065502
# 4    COC1=NC(=CN=C1CNCCO)C2=CC=CC(=C2F)C3=C(C(=CC=C...  0.213   9.671620
# ..                                                 ...    ...        ...
# 652  COC1=NC(=CN=C1CNC[C@@H]2CCC(=O)N2)C3=CC=CC(=C3...  0.121   9.917215
# 653  COC1=NC(=CN=C1CNCC2CCNC(=O)C2)C3=CC=CC(=C3Cl)C...  0.135   9.869666
# 654  COC1=NC(=CN=C1CNCC2CCNC2=O)C3=CC=CC(=C3Cl)C4=C...  0.064  10.193820
# 655  CC1=C(C=CC=C1C2=CN=C(C(=N2)OC)CN3CC4(C3)CN(C4)...  0.082  10.086186
# 656  CC(=O)NC[C@@H]1CCN(C1)CC2=NC=C(N=C2OC)C3=CC=CC...  0.281   9.551294
#
#      Nationality          A      Norm  C  D
# 0              0 -10.016910  1.009212  1  2
# ...
